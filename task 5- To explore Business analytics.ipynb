# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
a = df.groupby("Category")

# %%
a['Profit'].agg(func=[np.mean])
# Out:
#                       mean
# Category
# Furniture         8.699327
# Office Supplies  20.327050
# Technology       78.752002

# %% [markdown]
# # the mean profit is minimum for the Furniture category. So, the firm can look forward to increase its profit in this area.

# %%
sns.barplot(data=df,x='Category',y='Profit')
sns.set(rc={'figure.figsize':(15,15)})

# %%
sns.barplot(data=df,x='Ship Mode',y='Profit')
sns.set(rc={'figure.figsize':(15,15)})

# %%
sns.barplot(data=df,x='Region',y='Profit')
sns.set(rc={'figure.figsize':(15,15)})

# %%
# from the above graph we can see that the firm can improve its profit at Central Region.

# %%
a = df.groupby(['Category','Sub-Category'])

# %%
a.first()
# Out:
#                                    Ship Mode    Segment        Country  \
# Category        Sub-Category
# Furniture       Bookcases       Second Class   Consumer  United States
#                 Chairs          Second Class   Consumer  United States
#                 Furnishings   Standard Class   Consumer  United States
#                 Tables        Standard Class   Consumer  United States
# Office Supplies Appliances    Standard Class   Consumer  United States
#                 Art           Standard Class   Consumer  United States
#                 Binders       Standard Class   Consumer  United States
#                 Envelopes     Standard Class   Consumer  United States
#                 Fasteners     Standard Class  Corporate  United States
#                 Labels          Second Class  Corporate  United States
#                 Paper         Standard Class   Consumer  United States
#                 Storage       Standard Class   Consumer  United States
# ...

# %%
a['Quantity','Profit'].agg(func=[np.mean,np.std,'max','min'])
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                               Quantity                        Profit  \
#                                   mean       std max min        mean
# Category        Sub-Category
# Furniture       Bookcases     3.807018  2.283352  13   1  -15.230509
#                 Chairs        3.818476  2.282652  14   1   43.095894
#                 Furnishings   3.723093  2.155954  14   1   13.645918
#                 Tables        3.890282  2.446381  13   1  -55.565771
# Office Supplies Appliances    3.710300  2.123038  14   1   38.922758
#                 Art           3.768844  2.131957  14   1    8.200737
#                 Binders       3.922521  2.291913  14   1   19.843574
#                 Envelopes     3.566929  2.045299   9   1   27.418019
# ...

# %% [markdown]
# # from the above data we can set that the weak areas for the firm are as follows:
#
# # 1) Furniture - Tables and Bookcases.
# # 2) Office Supplies - Fasteners, Supplies and Art.

# %%
a = df.groupby(['Category','State','Sub-Category'])
a['Profit'].agg([np.mean])
# Out:
#                                            mean
# Category   State      Sub-Category
# Furniture  Alabama    Chairs         132.193280
#                       Furnishings      4.782933
#                       Tables         185.357667
#            Arizona    Bookcases     -289.735767
#                       Chairs           7.600306
# ...                                         ...
# Technology Washington Copiers       1888.484840
#                       Machines        87.866243
#                       Phones          19.959486
#            Wisconsin  Accessories    107.226571
#                       Phones          99.627064
#
# [656 rows x 1 columns]

# %% [markdown]
# # The following is the list of sub category items along with in which they are states going at loss for the firms.
#
# # Furniture Category
# # 1) Bookcases -  Arizona, Colorado, Florida, Illinois, North Calorina, Ohio,   Oregon, Pennsylvania, Tennessee, Texas.
# # 2) Tables - California, Colorado, Connecticut, Delaware, Florida, Illinois, Maryland, Massachusetts, New Hampshire, New Jersey, New York, North Carolina, Ohio, Oregon, Pennsylvania, Rhode Island, Tennessee, Texas,WestVirginia.'
# # 3) Chairs- Florida, Illinois, Nevada, Ohio, Pennsylvania, Texas.
# # 4) Furnishings - Illinois, Texas.
#
# # Office Supplies Category
# # 1) Binders - Arizona, Colorado, Florida, Illinois, North Carolina, Ohio, Oregon, Pennsylvania, Tennessee, Texas.
# # 2) Storage - Arizona, Colorado, Florida, Illinois, North Carolina, Ohio, Oregon, Pennsylvania, Tennessee, Texas.
# # 3) Supplies - Arizona, Colorado, Florida, North Carolina, Ohio, Oregon, Pennsylvania, Texas
# # 4) Appliances - Illinois, Texas.
#
# # Technology
# # 1) Machines - Colorado, Arizona, Florida, North Calorina, Ohio, Oregon, Pennsylvania, Tennessee, Texas.
# # 2) Phones - Ohio, Pennsylvania.

# %%
a = df.groupby(['Category','Segment','Sub-Category'])
a['Profit'].agg(func=[np.mean])
# Out:
#                                                 mean
# Category        Segment     Sub-Category
# Furniture       Consumer    Bookcases     -33.859834
#                             Chairs         40.228972
#                             Furnishings    16.031220
#                             Tables        -61.182628
#                 Corporate   Bookcases       9.975784
#                             Chairs         44.386471
#                             Furnishings    12.181277
#                             Tables        -46.287723
#                 Home Office Bookcases       9.837333
#                             Chairs         50.101779
#                             Furnishings     9.322933
#                             Tables        -57.239717
# Office Supplies Consumer    Appliances     28.614460
#                             Art             8.070797
#                             Binders        23.071278
#                             Envelopes      25.305524
# ...

# %% [markdown]
# # the above data show us the different subcategories in different segments which are at loss are as follows :-
#
# # --Furniture
# # 1) Consumer - Bookcases, Tables.
# # 2) Corporate - Tables.
# # 3) Home Office - Tables.
#
# # -- Office Supplies
# # 1) Consumer - Supplies

# %%
a = df.groupby(['Category','Ship Mode','Sub-Category'])
a['Profit'].agg(func=[np.mean])
# Out:
#                                               mean
# Category   Ship Mode      Sub-Category
# Furniture  First Class    Bookcases      -6.244847
#                           Chairs         31.120175
#                           Furnishings    14.336277
#                           Tables        -29.050351
#            Same Day       Bookcases      56.080800
# ...                                            ...
# Technology Second Class   Phones         47.872202
#            Standard Class Accessories    52.767705
#                           Copiers       870.961678
#                           Machines       35.183165
#                           Phones         48.601780
#
# [68 rows x 1 columns]

# %% [markdown]
# # the above data gives the different subcategories in different Ship Mode which are at loss are as follows:-
#
# # -- Furniture
# # 1) First Class - BookCases, Tables.
# # 2) Same Day - Tables.
# # 3) Second Class - Bookcases, Tables.
# # 4) Standard Class - Bookcases, Tables.
#
# # -- Office Supplies
# # 1) Second Class - Supplies.
# # 2) Standard Class - Supplies.
#
# # -- Technology
# # 1) First Class - Machines.
